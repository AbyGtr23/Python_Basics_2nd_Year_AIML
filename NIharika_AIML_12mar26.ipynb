# %%
#Q1.Write a Python program to print the following output:-

print("Hello world!")
print("Have a good day")
print("Learing python is fun")
# Out:
# Hello world!
# Have a good day
# Learing python is fun

# %%
#Q2.Write a Python program that prints the following using semicolon in one line:-

print("Hello;How are you?;bye bye")
# Out:
# Hello;How are you?;bye bye

# %%
#Q3.Write a Python program to print:-(make sure that 25 is not a part of string)

age=25
print("I am",age,"years old")
# Out:
# I am 25 years old

# %%
#Q4.Write a Python program to store your name and age in variables and print them.

a="niharika"
b=20
print(a,b)
# Out:
# niharika 20

# %%
# Q5Write a Python program to assign values "Apple", "Mango", and "Banana" to variables x, y,and z in one line, and print them.

x="Apple"
y="Mango"
z="Banana"
print(x,y,z)
# Out:
# Apple Mango Banana

# %%
#Q6.Write a Python program that:

a=5
print(str(a))
b=7.8
print(int(b))
c=9
print(float(c))
# Out:
# 5
# 7
# 9.0

# %%
#Q7.Write a program to store 10 in variable x, convert it into a string, and print its type.

x=10
x=str(x)
print(x)
print(type(x))
# Out:
# 10
# <class 'str'>

# %%
#Q8.Write a Python program that:

a=20
a=float(20)
print(a)
print(type(a))
# Out:
# 20.0
# <class 'float'>

# %%
sales_data=["1800","1200","900","1150","2560","1890","2200"]
sales_int=[]
for i in sales_data;
    if type(i)=='int';
        sales_int.append(i)
        else;
sales
# Out:
# ['1800', '1200', '900', '1150', '2560', '1890', '2200']
