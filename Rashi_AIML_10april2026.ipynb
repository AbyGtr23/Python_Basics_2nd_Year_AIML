# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
for i in list1:
    print(type(i))
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'list'>

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.extend(['ABC','DEF'])
print(list1)
# Out:
# ['a', 'b', 'c', 'd', 'ABC', 'DEF']

# %%
#insert operation
list1.insert(1,'XYZ')
print(list1)
# Out:
# ['a', 'XYZ', 'b', 'c', 'd', 'ABC', 'DEF']

# %%
#pop operation
list1.pop(1)
print(list1)
# Out:
# ['a', 'd', 'DEF']

# %%
#remove opration 
list1.remove('a')
print(list1)
# Out:
# ['d', 'DEF']

# %%
#conversion of of database
list1=[1,1,2,2,3,3,4,4]
s=set(list1)
print(s)
T=tuple(list1)
print(T)
# Out:
# {1, 2, 3, 4}
# (1, 1, 2, 2, 3, 3, 4, 4)

# %%
#set operation
S2=set('aahhbgff')
print(S2)
# Out:
# {'b', 'f', 'h', 'g', 'a'}

# %%
S3={0,'1',True,'True'}
print(S3)
# Out:
# {0, True, '1', 'True'}

# %%
#using index
L1=[1,2,3,4]
print(L1[1])
# Out:
# 2

# %%
D1={"name":'Rashi',"roll no": '48', "address" :'NAGPUR'}
print(D1['roll no'])
# Out:
# 48

# %%
listA=['a','b','c','d']
listB=[1,2,3,4]
D2=dict(zip(listA,listB))
print(D2)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
for x in D1.keys():
 print(x)
for y in D1.values():
  print(y)
# Out:
# name
# roll no
# address
# Rashi
# 48
# NAGPUR

# %%
for x,y in D1.items():
            print(x,y)
# Out:
# name Rashi
# roll no 48
# address NAGPUR
