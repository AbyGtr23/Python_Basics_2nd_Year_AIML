# %%
print("Hello, World!")
print("Having a good day")
print("Learning python is fun")
# Out:
# Hello, World!
# Having a good day
# Learning python is fun

# %%
print("Hello\n How are you?\n Bye bye")
print("Hello");print("how are you?");print("Bye bye")
# Out:
# Hello
#  How are you?
#  Bye bye
# Hello
# how are you?
# Bye bye

# %%
x=25
print(f"i am {x} years old")
# Out:
# i am 25 years old

# %%
x="Rashi harde" ; y=19
print(f"{x}! you are {y} years old.")
# Out:
# Rashi harde! you are 19 years old.

# %%
sale_data =["1800","1200","900","1150","2500","1890","2200"]
s=[1,2,3]
print(sale_data)
print(s)
ans=[]
for i in sale_data:
  ans.append(int(i))

print(ans)
# Out:
# ['1800', '1200', '900', '1150', '2500', '1890', '2200']
# [1, 2, 3]
# [1800, 1200, 900, 1150, 2500, 1890, 2200]

# %%
int_num = 5
str_num =str(int_num)
print(f"integer 5 as string : '{str_num}' (type:{type(str_num)})")

float_num =7.8
int_result = int(float_num)
print(f"float 7.8 as integer : {int_result} (type: {type(int_result)})")
# Out:
# integer 5 as string : '5' (type:<class 'str'>)
# float 7.8 as integer : 7 (type: <class 'int'>)
