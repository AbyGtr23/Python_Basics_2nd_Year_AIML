# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
list1.extend(['ABC','DEF'])
print(list1)
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# ['a', 'b', 'c', 'd', [1, 2, 3], 'ABC', 'DEF']

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.insert(1,'XYZ')
print(list1)
# Out:
# ['a', 'XYZ', 'b', 'c', 'd']

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.pop(1)
print(list1)
# Out:
# ['a', 'c', 'd']

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.remove('b')
print(list1)
# Out:
# ['a', 'c', 'd']

# %%
list1=[1,2,3,3]
t=tuple(list1)
print(list1)
# Out:
# [1, 2, 3, 3]

# %%
list=[1,2,3,3]
s=set(list1)
print(list1)
# Out:
# [1, 2, 3, 3]

# %%
S2='aabbccddee'
print(type(S2))
# Out:
# <class 'str'>

# %%
S3={0,1,'1',True,'True'}
print(S3)
# Out:
# {0, 1, '1', 'True'}

# %%
L1=['a','b','c','d']
print(L1[2])
# Out:
# c

# %%
D1={"Name":"sarode",
"Roll No":"014",
"address":"XYZ,Ngpur"}
print(D1)
print(type(D1))
print(D1["Roll No"])
# Out:
# {'Name': 'sarode', 'Roll No': '014', 'address': 'XYZ,Ngpur'}
# <class 'dict'>
# 014

# %%
listA =['a','b','c']
listB =[1,2,3]
D2 =dict(zip(listA,listB))
print(D2)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
D1={"Name":"sarode",
"Roll No":"014",
"address":"XYZ,Ngpur"}
for x in D1.keys():
    print(x)
for y in D1.values():
    print(y)
for x,y in D1.items():
    print(x,y)
# Out:
# Name
# Roll No
# address
# sarode
# 014
# XYZ,Ngpur
# Name sarode
# Roll No 014
# address XYZ,Ngpur
