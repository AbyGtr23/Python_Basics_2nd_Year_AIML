# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
print(type(list1))
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# <class 'list'>

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
for i in list1:
    print(type(i))
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'list'>

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
list1.extend(['ABC','DCE'])
print(list1)
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# ['a', 'b', 'c', 'd', [1, 2, 3], 'ABC', 'DCE']

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
list1.extend(['ABC','DCE'])
print(list1)
list1.insert(10,'XYZ')
print(list1)
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# ['a', 'b', 'c', 'd', [1, 2, 3], 'ABC', 'DCE']
# ['a', 'b', 'c', 'd', [1, 2, 3], 'ABC', 'DCE', 'XYZ']

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
list1.extend(['ABC','DCE'])
print(list1)
list1.pop(1)
print(list1)
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# ['a', 'b', 'c', 'd', [1, 2, 3], 'ABC', 'DCE']
# ['a', 'c', 'd', [1, 2, 3], 'ABC', 'DCE']

# %%
list1=['a','b','c','d']
list2=['apple','ball','cat','dog']
list1.append([1,2,3])
print(list1)
list1.extend(['ABC','DCE'])
print(list1)
list1.remove('ABC')
print(list1)
# Out:
# ['a', 'b', 'c', 'd', [1, 2, 3]]
# ['a', 'b', 'c', 'd', [1, 2, 3], 'ABC', 'DCE']
# ['a', 'b', 'c', 'd', [1, 2, 3], 'DCE']

# %%
list1=[1,1,2,2,3,3]
S=set(list1)
T=tuple(list1)
print(S)
print(T)
S2=set('aabbccddee')
print(S2)
# Out:
# {1, 2, 3}
# (1, 1, 2, 2, 3, 3)
# {'e', 'b', 'c', 'a', 'd'}

# %%
S3={0,1,'1',True,'True'}
#(1 or True) boolean value hai is liye set (1 or True) mese ek hi value dikhayenga
print(S3)
# Out:
# {0, 1, 'True', '1'}

# %%
l1=['a','b','c','d']
print(l1[2])
# Out:
# c

# %%
D1={"Name":"Vaishnavi","Roll_no":"018","Address":"Koradi"}
print(D1)
print(type(D1))
# Out:
# {'Name': 'Vaishnavi', 'Roll_no': '018', 'Address': 'Koradi'}
# <class 'dict'>

# %%
D1={"Name":"Vaishnavi","Roll_no":"018","Address":"Koradi"}
print(D1)
print(type(D1))
print(D1["Roll_no"])
# Out:
# {'Name': 'Vaishnavi', 'Roll_no': '018', 'Address': 'Koradi'}
# <class 'dict'>
# 018

# %%
listA=['a','b','c']
listB=[1,2,3]
D2=dict(zip(listA,listB))
print(D2)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
D1={"Name":"Vaishnavi","Roll_no":"018","Address":"Koradi"}
print(D1)
for x in D1.keys():
    print(x)
# Out:
# {'Name': 'Vaishnavi', 'Roll_no': '018', 'Address': 'Koradi'}
# Name
# Roll_no
# Address

# %%
D1={"Name":"Vaishnavi","Roll_no":"018","Address":"Koradi"}
print(D1)
for y in D1.values():
    print(y)
# Out:
# {'Name': 'Vaishnavi', 'Roll_no': '018', 'Address': 'Koradi'}
# Vaishnavi
# 018
# Koradi
