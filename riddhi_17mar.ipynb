# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>
# 12.5
# <class 'float'>

# %%
b=12.5
b=float(b)
print(b)
print(type(b))
# Out:
# 12.5
# <class 'float'>

# %%
c=90
c=str(c)
print(c)
print(type(c))
# Out:
# 90
# <class 'str'>

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
list1=["a","b",2,9.0,"false"]
list1[4]="true"
print(type(list1[3]))
print(list1)
# Out:
# <class 'float'>
# ['a', 'b', 2, 9.0, 'true']

# %%
tuple=("riddhi","unnati",9.0,"true","riddhi")
print(tuple.count("riddhi"))
print(tuple)
# Out:
# 2
# ('riddhi', 'unnati', 9.0, 'true', 'riddhi')
